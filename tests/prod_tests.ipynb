# %%
import sys
import os
wd = %pwd
parent = os.path.dirname(wd)
fdel = os.path.sep
sys.path.append(parent+fdel+"src")
import tedata as ted

# %%
search = ted.search_TE()
search.search_trading_economics("australia consumer confidence")
search.result_table
# Out:
# Loading home page...
# Clicking search box...
# Entering search term: australia consumer confidence
# Submitting search...
#           country                                            metric  \
# result
# 0       australia                               consumer confidence
# 1       australia                           consumer confidence mom
# 2       australia  consumer confidence major purchases expectations
# 3       australia            consumer confidence current conditions
# 4       australia         consumer confidence economic expectations
# 5       australia        consumer confidence financial expectations
#
#                                                       url
# result
# 0       https://tradingeconomics.com/australia/consume...
# 1       https://tradingeconomics.com/australia/consume...
# 2       https://tradingeconomics.com/australia/consume...
# 3       https://tradingeconomics.com/australia/consume...
# 4       https://tradingeconomics.com/australia/consume...
# 5       https://tradingeconomics.com/australia/consume...

# %%
search.get_data(0)
# Out:
# Attempting to scrape data for result  0 ,  australia consumer confidence
# Scraping data from: https://tradingeconomics.com/australia/consumer-confidence
# Page at  https://tradingeconomics.com/australia/consumer-confidence , loaded successfully.
# a.hawk-chartOptions-datePicker-cnt-btn:nth-child(5)
# Button clicked successfully, waiting 2s for response...
# Clicked the MAX button successfully.
# yax:  [40.0, 335.0]
# xax:  [25.0, 690.0]
# y-axis labels:  [59.0, 70.0, 82.0, 94.0, 106.0, 118.0, 128.0]
# Average px per unit for y-axis:  0.23323625685953597
# Successfully scraped y-axis values from the chart:
#  pixheight
# 39.5      59
# 83.5      70
# 134.5     82
# 185.5     94
# 237.5    106
# 288.5    118
# 335.5    128
# Name: ytick_label, dtype: int64
# Successfully scraped raw pixel co-ordinate seruies from the path element in chart:
#  0.000000      176.028986
# 0.000000      176.028986
# 0.651074      177.669043
# 1.085124      178.594203
# 1.533642      179.550202
#                  ...
# 663.444656    187.109884
# 663.878705    185.007246
# 664.327223    182.834521
# 665.000000    182.014493
# 665.000000    182.014493
# Name: Extracted Series, Length: 1813, dtype: float64
# Using selenium and toltip scraping to construct the date time index for the time-series, this'll take a bit...
# Viewport dimensions: 1366 x 683
# Chart position in viewport: x=144.0, y=467.0
# Tooltip not found
# Error scraping tooltip at (144.0, 614.5), error: object of type 'NoneType' has no len()
# Scraping the last point now at x =  809.0
#
#
# Time series frequency appears to be: 31, MS
#
#
# Start and end values scraped from tooltips:  {'start_date': Timestamp('1974-09-01 00:00:00'), 'end_date': Timestamp('2025-01-01 00:00:00'), 'start_value': 90.7, 'end_value': 92.1}
# Creating date index for self.series, using start and end dates from tooltips stored in self.start_end.
# Date index created successfully. Take a look at the final series:
#
#  1974-09-01    176.028986
# 1974-10-01    178.594203
# 1974-11-01    181.572939
# 1974-12-01    182.869565
# 1975-01-01    219.295652
#                  ...
# 2024-09-01    149.949275
# 2024-10-01    172.181159
# 2024-11-01    192.702899
# 2024-12-01    185.007246
# 2025-01-01    182.014493
# Freq: MS, Name: consumer confidence, Length: 605, dtype: float64
# Start value, end value 90.7 92.1 pix0, pix1 176.02898550725 182.01449275362
# Start value, end value 90.7 92.1  pix0, pix1 176.02898550725 182.01449275362 data units perchar pixel from start & end points:  0.23389830508501086
#  unit_per_pix calculated from the y axis ticks:  0.23323625685953597
#  inverse of that:  4.287498065115319
#  unit_per_pix from axis limits and self.y_axis (probably best way):  0.23389830508474577
# Successfully scraped time-series from chart at:  https://tradingeconomics.com/australia/consumer-confidence
#  1974-09-01     90.700000
# 1974-10-01     91.300000
# 1974-11-01     91.996721
# 1974-12-01     92.300000
# 1975-01-01    100.820000
#                  ...
# 2024-09-01     84.600000
# 2024-10-01     89.800000
# 2024-11-01     94.600000
# 2024-12-01     92.800000
# 2025-01-01     92.100000
# Freq: MS, Name: consumer confidence, Length: 605, dtype: float64 now getting some metadata...
# Series metadata:  {'units': 'points', 'original_source': 'Westpac Banking Corporation, Melbourne Institute', 'title': 'Australia Consumer Confidence', 'country': 'australia', 'length': 605, 'frequency': 'MS', 'source': 'Trading Economics', 'id': 'australia/consumer-confidence', 'start_date': '1974-09-01', 'end_date': '2025-01-01', 'min_value': 64.5999999999991, 'max_value': 123.8999999999983}
# Check the metadata:  {'units': 'points', 'original_source': 'Westpac Banking Corporation, Melbourne Institute', 'title': 'Australia Consumer Confidence', 'country': 'australia', 'length': 605, 'frequency': 'MS', 'source': 'Trading Economics', 'id': 'australia/consumer-confidence', 'start_date': '1974-09-01', 'end_date': '2025-01-01', 'min_value': 64.5999999999991, 'max_value': 123.8999999999983, 'description': "The Consumer Sentiment Index is based on a survey of over 1,200 Australian households. The Index is an average of five component indexes which reflect consumers' evaluations of their household financial situation over the past year and the coming year, anticipated economic conditions over the coming year and the next five years, and buying conditions for major household items. The index scores above 100 indicate that optimists outweigh pessimists."}
# Scraping complete! Happy pirating yo!

# %%
scraped = search.scraped_data
scraped.plot_series()

# %%
scraped = ted.scrape_chart(id = "corporate-profits")
# Out:
# Page at  https://tradingeconomics.com/united-states/corporate-profits , loaded successfully.
# a.hawk-chartOptions-datePicker-cnt-btn:nth-child(4)
# Button clicked successfully, waiting 2s for response...
# Clicked the MAX button successfully.
# yax:  [40.0, 335.0]
# xax:  [25.0, 684.0]
# y-axis labels:  [-200.0, 0.0, 600.0, 1200.0, 1800.0, 2400.0, 3000.0, 3400.0]
# Average px per unit for y-axis:  13.123134968273023
# Successfully scraped y-axis values from the chart:
#  pixheight
# 39.5     -200
# 73.5        0
# 122.5     600
# 171.5    1200
# 220.5    1800
# 269.5    2400
# 319.5    3000
# 335.5    3400
# Name: ytick_label, dtype: int64
# Successfully scraped raw pixel co-ordinate seruies from the path element in chart:
#  0.000000       57.704974
# 0.000000       57.704974
# 1.284991       57.981864
# 2.141651       58.003579
# 2.998311       58.025294
#                  ...
# 656.001689    314.322032
# 656.858349    314.322032
# 657.715009    314.322032
# 659.000000    313.252083
# 659.000000    313.252083
# Name: Extracted Series, Length: 931, dtype: float64
# Using selenium and toltip scraping to construct the date time index for the time-series, this'll take a bit...
# Viewport dimensions: 1366 x 683
# Chart position in viewport: x=144.0, y=399.0
# Tooltip not found
# Error scraping tooltip at (144.0, 546.5), error: object of type 'NoneType' has no len()
# Scraping the last point now at x =  803.0
#
#
# Time series frequency appears to be: 91, QS
#
#
# Start and end values scraped from tooltips:  {'start_date': Timestamp('1947-01-01 00:00:00'), 'end_date': Timestamp('2024-07-01 00:00:00'), 'start_value': 9.959, 'end_value': 3130.0}
# Creating date index for self.series, using start and end dates from tooltips stored in self.start_end.
# Date index created successfully. Take a look at the final series:
#
#  1947-01-01     57.704974
# 1947-04-01     58.003579
# 1947-07-01     58.025294
# 1947-10-01     58.073396
# 1948-01-01     58.361513
#                  ...
# 2023-07-01    298.874029
# 2023-10-01    311.066953
# 2024-01-01    305.729747
# 2024-04-01    314.322032
# 2024-07-01    313.252083
# Freq: QS-JAN, Name: corporate profits, Length: 311, dtype: float64
# Start value, end value 9.959 3130.0 pix0, pix1 57.70497361111097 313.25208333333
# Start value, end value 9.959 3130.0  pix0, pix1 57.70497361111097 313.25208333333 data units perchar pixel from start & end points:  12.209259589715181
#  unit_per_pix calculated from the y axis ticks:  13.123134968273023
#  inverse of that:  0.07620130421714301
#  unit_per_pix from axis limits and self.y_axis (probably best way):  12.203389830508474
# Successfully scraped time-series from chart at:  https://tradingeconomics.com/united-states/corporate-profits
#  1947-01-01       9.959
# 1947-04-01      13.603
# 1947-07-01      13.868
# 1947-10-01      14.455
# 1948-01-01      17.971
#                 ...
# 2023-07-01    2953.039
# 2023-10-01    3101.834
# 2024-01-01    3036.702
# 2024-04-01    3141.557
# 2024-07-01    3128.500
# Freq: QS-JAN, Name: corporate profits, Length: 311, dtype: float64 now getting some metadata...
# Series metadata:  {'units': 'USD Billion', 'original_source': 'U.S. Bureau of Economics Analysis', 'title': 'United States Corporate Profits', 'country': 'united states', 'length': 311, 'frequency': 'QS', 'source': 'Trading Economics', 'id': 'united-states/corporate-profits', 'start_date': '1947-01-01', 'end_date': '2024-07-01', 'min_value': 9.959, 'max_value': 3141.5569999999475}
# Check the metadata:  {'units': 'USD Billion', 'original_source': 'U.S. Bureau of Economics Analysis', 'title': 'United States Corporate Profits', 'country': 'united states', 'length': 311, 'frequency': 'QS', 'source': 'Trading Economics', 'id': 'united-states/corporate-profits', 'start_date': '1947-01-01', 'end_date': '2024-07-01', 'min_value': 9.959, 'max_value': 3141.5569999999475, 'description': 'Corporate profits represents the portion of the total income earned from current production that is accounted for by U.S. corporations. It is one of the most closely watched U.S. economic indicators, as it provides a summary measure of corporate financial health and thus serves as an essential indicator of economic performance.'}
# Scraping complete! Happy pirating yo!

# %%
scraped.plot_series()
