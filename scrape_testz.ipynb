# %%
import scrape as scr
import time
import json
from bs4 import BeautifulSoup
import pandas as pd
pd.options.plotting.backend = "plotly"

from selenium import webdriver

# %%
sel = scr.TE_Scraper(browser='firefox')
sel.load_page("https://tradingeconomics.com/united-states/non-manufacturing-pmi")
sel.click_button("a.hawk-chartOptions-datePicker-cnt-btn:nth-child(5)")
# Out:
# True

# %%
yaxys = sel.get_y_axis()
yaxys
# Out:
# Average px per unit for y-axis:  0.11881136950904392
# pixheight
# 39.5     35.0
# 82.5     41.0
# 133.5    47.0
# 183.5    53.0
# 234.5    59.0
# 284.5    65.0
# 335.5    70.0
# Name: ytick_label, dtype: float64

# %%
sel.get_element()
series = sel.series_from_element(invert_the_series=True)
sel.series
# Out:
# 0.000000      223.400000
# 0.000000      223.400000
# 1.251798      268.071429
# 2.086329      268.071429
# 2.920861      268.071429
#                  ...
# 669.106059    217.500000
# 669.913671    217.500000
# 670.748202    217.500000
# 672.000000    184.628571
# 672.000000    184.628571
# Name: Extracted Series, Length: 985, dtype: float64

# %%
sel.series.max()
# Out:
# np.float64(315.27142857143)

# %%
fig = sel.series.plot()

# Add horizontal lines and labels
for i in range(len(yaxys)):
    fig.add_shape(
        type='line',
        x0=sel.series.index.min(),
        y0=yaxys.index[i],
        x1=sel.series.index.max(),
        y1=yaxys.index[i],
        line=dict(color='Red', dash='dash')
    )
    fig.add_annotation(
        x=sel.series.index.max(),  # Position the label at the end of the line
        y=yaxys.index[i],
        text=str(yaxys.iloc[i]),
        showarrow=False,
        xanchor='left',
        yanchor='middle'
    )

# Show the figure
fig.show()

# %%
sel.make_x_index()
# Out:
# Viewport dimensions: 1366 x 683
# Chart position in viewport: x=143.0, y=467.0
# Moving to first point at viewport coordinates (143.0, 614.5)
# No tooltip found for first point
# Moving to last point at viewport coordinates (815.0, 614.5)
# <g class="highcharts-tooltip" data-z-index="8" opacity="1"><g class="highcharts-label highcharts-tooltip-box highcharts-color-none" transform="translate(590,159)" style="cursor: default; white-space: nowrap;"><path fill="none" class="highcharts-label-box highcharts-shadow" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 25.871428571429988 L 96.5 31.871428571429988 L 90.5 37.87142857142999 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#000000" stroke-opacity="0.049999999999999996" stroke-width="5" transform="translate(1, 1)"></path><path fill="none" class="highcharts-label-box highcharts-shadow" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 25.871428571429988 L 96.5 31.871428571429988 L 90.5 37.87142857142999 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#000000" stroke-opacity="0.09999999999999999" stroke-width="3" transform="translate(1, 1)"></path><path fill="none" class="highcharts-label-box highcharts-shadow" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 25.871428571429988 L 96.5 31.871428571429988 L 90.5 37.87142857142999 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#000000" stroke-opacity="0.15" stroke-width="1" transform="translate(1, 1)"></path><path fill="rgba(247,247,247,0.85)" class="highcharts-label-box" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 25.871428571429988 L 96.5 31.871428571429988 L 90.5 37.87142857142999 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#4f81bd" stroke-width="1"></path></g></g>
# <div class="highcharts-tooltip" style="position: absolute; left: 0px; top: 0px; opacity: 1; visibility: inherit;"><div class="highcharts-label highcharts-tooltip-box highcharts-color-none" style="position: absolute; left: 590px; top: 159px; opacity: 1; visibility: inherit;"><span style="position: absolute; font-family: &quot;Lucida Grande&quot;, &quot;Lucida Sans Unicode&quot;, Arial, Helvetica, sans-serif; font-size: 12px; white-space: nowrap; margin-left: 0px; margin-top: 0px; left: 0px; top: 0px; color: rgb(51, 51, 51);" data-z-index="1"><div class="tooltip-box"><span class="tooltip-date">Nov 2024</span><hr class="tooltip-divider"><span class="hawk-tt tooltip-value" style="color: rgb(51, 51, 51);"> 52.1 Points</span></div></span></div></div>
# Found last point data: <div class="highcharts-tooltip" style="position: absolute; left: 0px; top: 0px; opacity: 1; visibility: inherit;"><div class="highcharts-label highcharts-tooltip-box highcharts-color-none" style="position: absolute; left: 590px; top: 159px; opacity: 1; visibility: inherit;"><span style="position: absolute; font-family: &quot;Lucida Grande&quot;, &quot;Lucida Sans Unicode&quot;, Arial, Helvetica, sans-serif; font-size: 12px; white-space: nowrap; margin-left: 0px; margin-top: 0px; left: 0px; top: 0px; color: rgb(51, 51, 51);" data-z-index="1"><div class="tooltip-box"><span class="tooltip-date">Nov 2024</span><hr class="tooltip-divider"><span class="hawk-tt tooltip-value" style="color: rgb(51, 51, 51);"> 52.1 Points</span></div></span></div></div>
# Viewport dimensions: 1366 x 683
# Chart position in viewport: x=143.0, y=467.0
# Moving to first point at viewport coordinates (143.0, 614.5)
# <g class="highcharts-tooltip" data-z-index="8" opacity="1" y="-9999"><g class="highcharts-label highcharts-tooltip-box highcharts-color-none" transform="translate(41,120)" style="cursor: default; white-space: nowrap;"><path fill="none" class="highcharts-label-box highcharts-shadow" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 38.099999999999994 L -5.5 32.099999999999994 L 0.5 26.099999999999994 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#000000" stroke-opacity="0.049999999999999996" stroke-width="5" transform="translate(1, 1)"></path><path fill="none" class="highcharts-label-box highcharts-shadow" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 38.099999999999994 L -5.5 32.099999999999994 L 0.5 26.099999999999994 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#000000" stroke-opacity="0.09999999999999999" stroke-width="3" transform="translate(1, 1)"></path><path fill="none" class="highcharts-label-box highcharts-shadow" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 38.099999999999994 L -5.5 32.099999999999994 L 0.5 26.099999999999994 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#000000" stroke-opacity="0.15" stroke-width="1" transform="translate(1, 1)"></path><path fill="rgba(247,247,247,0.85)" class="highcharts-label-box" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 38.099999999999994 L -5.5 32.099999999999994 L 0.5 26.099999999999994 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#4f81bd" stroke-width="1"></path></g></g>
# <div class="highcharts-tooltip" style="position: absolute; left: 0px; top: 0px; opacity: 1; visibility: inherit;"><div class="highcharts-label highcharts-tooltip-box highcharts-color-none" style="position: absolute; left: 41px; top: 120px; opacity: 1; visibility: inherit;"><span style="position: absolute; font-family: &quot;Lucida Grande&quot;, &quot;Lucida Sans Unicode&quot;, Arial, Helvetica, sans-serif; font-size: 12px; white-space: nowrap; margin-left: 0px; margin-top: 0px; left: 0px; top: 0px; color: rgb(51, 51, 51);" data-z-index="1"><div class="tooltip-box"><span class="tooltip-date">Jul 1997</span><hr class="tooltip-divider"><span class="hawk-tt tooltip-value" style="color: rgb(51, 51, 51);"> 56.7 Points</span></div></span></div></div>
# Found first point data: <div class="highcharts-tooltip" style="position: absolute; left: 0px; top: 0px; opacity: 1; visibility: inherit;"><div class="highcharts-label highcharts-tooltip-box highcharts-color-none" style="position: absolute; left: 41px; top: 120px; opacity: 1; visibility: inherit;"><span style="position: absolute; font-family: &quot;Lucida Grande&quot;, &quot;Lucida Sans Unicode&quot;, Arial, Helvetica, sans-serif; font-size: 12px; white-space: nowrap; margin-left: 0px; margin-top: 0px; left: 0px; top: 0px; color: rgb(51, 51, 51);" data-z-index="1"><div class="tooltip-box"><span class="tooltip-date">Jul 1997</span><hr class="tooltip-divider"><span class="hawk-tt tooltip-value" style="color: rgb(51, 51, 51);"> 56.7 Points</span></div></span></div></div>
# Moving to last point at viewport coordinates (815.0, 614.5)
# <g class="highcharts-tooltip" data-z-index="8" opacity="1" y="-9999"><g class="highcharts-label highcharts-tooltip-box highcharts-color-none" transform="translate(590,159)" style="cursor: default; white-space: nowrap;"><path fill="none" class="highcharts-label-box highcharts-shadow" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 25.871428571429988 L 96.5 31.871428571429988 L 90.5 37.87142857142999 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#000000" stroke-opacity="0.049999999999999996" stroke-width="5" transform="translate(1, 1)"></path><path fill="none" class="highcharts-label-box highcharts-shadow" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 25.871428571429988 L 96.5 31.871428571429988 L 90.5 37.87142857142999 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#000000" stroke-opacity="0.09999999999999999" stroke-width="3" transform="translate(1, 1)"></path><path fill="none" class="highcharts-label-box highcharts-shadow" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 25.871428571429988 L 96.5 31.871428571429988 L 90.5 37.87142857142999 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#000000" stroke-opacity="0.15" stroke-width="1" transform="translate(1, 1)"></path><path fill="rgba(247,247,247,0.85)" class="highcharts-label-box" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 25.871428571429988 L 96.5 31.871428571429988 L 90.5 37.87142857142999 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#4f81bd" stroke-width="1"></path></g></g>
# <div class="highcharts-tooltip" style="position: absolute; left: 0px; top: 0px; opacity: 1; visibility: inherit;"><div class="highcharts-label highcharts-tooltip-box highcharts-color-none" style="position: absolute; left: 590px; top: 159px; opacity: 1; visibility: inherit;"><span style="position: absolute; font-family: &quot;Lucida Grande&quot;, &quot;Lucida Sans Unicode&quot;, Arial, Helvetica, sans-serif; font-size: 12px; white-space: nowrap; margin-left: 0px; margin-top: 0px; left: 0px; top: 0px; color: rgb(51, 51, 51);" data-z-index="1"><div class="tooltip-box"><span class="tooltip-date">Nov 2024</span><hr class="tooltip-divider"><span class="hawk-tt tooltip-value" style="color: rgb(51, 51, 51);"> 52.1 Points</span></div></span></div></div>
# Found last point data: <div class="highcharts-tooltip" style="position: absolute; left: 0px; top: 0px; opacity: 1; visibility: inherit;"><div class="highcharts-label highcharts-tooltip-box highcharts-color-none" style="position: absolute; left: 590px; top: 159px; opacity: 1; visibility: inherit;"><span style="position: absolute; font-family: &quot;Lucida Grande&quot;, &quot;Lucida Sans Unicode&quot;, Arial, Helvetica, sans-serif; font-size: 12px; white-space: nowrap; margin-left: 0px; margin-top: 0px; left: 0px; top: 0px; color: rgb(51, 51, 51);" data-z-index="1"><div class="tooltip-box"><span class="tooltip-date">Nov 2024</span><hr class="tooltip-divider"><span class="hawk-tt tooltip-value" style="color: rgb(51, 51, 51);"> 52.1 Points</span></div></span></div></div>
# Creating date index for self.series, using start and end dates from tooltips stored in self.start_end.
# Date index created successfully. Take a look at the final series:
#
#  1997-07-01    223.400000
# 1997-08-01    268.071429
# 1997-09-01    219.185714
# 1997-10-01    225.928571
# 1997-11-01    238.571429
#                  ...
# 2024-07-01    178.728571
# 2024-08-01    179.571429
# 2024-09-01    208.228571
# 2024-10-01    217.500000
# 2024-11-01    184.628571
# Freq: MS, Name: US_ISM_Services_PMI, Length: 329, dtype: float64

# %%
sel.plot_series()

# %%
sel.get_datamax_min()
# Out:
# axisY0 =  35 axisY1 = 70
# unit_per_pix:  0.11824324324324324
# datamax:  67.608 datamin:  37.909

# %%
sel.scale_series(right_way_up=True)
sel.series
# Out:
# 1997-07-01    56.744943
# 1997-08-01    62.026980
# 1997-09-01    56.246638
# 1997-10-01    57.043926
# 1997-11-01    58.538842
#                 ...
# 2024-07-01    51.462906
# 2024-08-01    51.562567
# 2024-09-01    54.951044
# 2024-10-01    56.047315
# 2024-11-01    52.160534
# Freq: MS, Name: US_ISM_Services_PMI, Length: 329, dtype: float64

# %%
sel.series.plot()

# %%
sel2 = scr.scrape_chart("https://tradingeconomics.com/united-states/non-manufacturing-pmi")
# Out:
# Page at  https://tradingeconomics.com/united-states/non-manufacturing-pmi , loaded successfully.
# Clicked the MAX button successfully.
# Average px per unit for y-axis:  0.11881136950904392
# Successfully scraped y-axis values from the chart:
#  pixheight
# 39.5     35
# 82.5     41
# 133.5    47
# 183.5    53
# 234.5    59
# 284.5    65
# 335.5    70
# Name: ytick_label, dtype: int64
# Successfully scraped raw pixel co-ordinate seruies from the path element in chart:
#  0.000000      223.400000
# 0.000000      223.400000
# 1.251798      268.071429
# 2.086329      268.071429
# 2.920861      268.071429
#                  ...
# 669.106059    217.500000
# 669.913671    217.500000
# 670.748202    217.500000
# 672.000000    184.628571
# 672.000000    184.628571
# Name: Extracted Series, Length: 985, dtype: float64
# Viewport dimensions: 1366 x 683
# Chart position in viewport: x=143.0, y=467.0
# Moving to first point at viewport coordinates (143.0, 614.5)
# No tooltip found for first point
# Moving to last point at viewport coordinates (815.0, 614.5)
# <g class="highcharts-tooltip" data-z-index="8" opacity="1"><g class="highcharts-label highcharts-tooltip-box highcharts-color-none" transform="translate(590,159)" style="cursor: default; white-space: nowrap;"><path fill="none" class="highcharts-label-box highcharts-shadow" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 25.871428571429988 L 96.5 31.871428571429988 L 90.5 37.87142857142999 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#000000" stroke-opacity="0.049999999999999996" stroke-width="5" transform="translate(1, 1)"></path><path fill="none" class="highcharts-label-box highcharts-shadow" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 25.871428571429988 L 96.5 31.871428571429988 L 90.5 37.87142857142999 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#000000" stroke-opacity="0.09999999999999999" stroke-width="3" transform="translate(1, 1)"></path><path fill="none" class="highcharts-label-box highcharts-shadow" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 25.871428571429988 L 96.5 31.871428571429988 L 90.5 37.87142857142999 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#000000" stroke-opacity="0.15" stroke-width="1" transform="translate(1, 1)"></path><path fill="rgba(247,247,247,0.85)" class="highcharts-label-box" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 25.871428571429988 L 96.5 31.871428571429988 L 90.5 37.87142857142999 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#4f81bd" stroke-width="1"></path></g></g>
# <div class="highcharts-tooltip" style="position: absolute; left: 0px; top: 0px; opacity: 1; visibility: inherit;"><div class="highcharts-label highcharts-tooltip-box highcharts-color-none" style="position: absolute; left: 590px; top: 159px; opacity: 1; visibility: inherit;"><span style="position: absolute; font-family: &quot;Lucida Grande&quot;, &quot;Lucida Sans Unicode&quot;, Arial, Helvetica, sans-serif; font-size: 12px; white-space: nowrap; margin-left: 0px; margin-top: 0px; left: 0px; top: 0px; color: rgb(51, 51, 51);" data-z-index="1"><div class="tooltip-box"><span class="tooltip-date">Nov 2024</span><hr class="tooltip-divider"><span class="hawk-tt tooltip-value" style="color: rgb(51, 51, 51);"> 52.1 Points</span></div></span></div></div>
# Found last point data: <div class="highcharts-tooltip" style="position: absolute; left: 0px; top: 0px; opacity: 1; visibility: inherit;"><div class="highcharts-label highcharts-tooltip-box highcharts-color-none" style="position: absolute; left: 590px; top: 159px; opacity: 1; visibility: inherit;"><span style="position: absolute; font-family: &quot;Lucida Grande&quot;, &quot;Lucida Sans Unicode&quot;, Arial, Helvetica, sans-serif; font-size: 12px; white-space: nowrap; margin-left: 0px; margin-top: 0px; left: 0px; top: 0px; color: rgb(51, 51, 51);" data-z-index="1"><div class="tooltip-box"><span class="tooltip-date">Nov 2024</span><hr class="tooltip-divider"><span class="hawk-tt tooltip-value" style="color: rgb(51, 51, 51);"> 52.1 Points</span></div></span></div></div>
# Viewport dimensions: 1366 x 683
# Chart position in viewport: x=143.0, y=467.0
# Moving to first point at viewport coordinates (143.0, 614.5)
# <g class="highcharts-tooltip" data-z-index="8" opacity="1" y="-9999"><g class="highcharts-label highcharts-tooltip-box highcharts-color-none" transform="translate(41,120)" style="cursor: default; white-space: nowrap;"><path fill="none" class="highcharts-label-box highcharts-shadow" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 38.099999999999994 L -5.5 32.099999999999994 L 0.5 26.099999999999994 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#000000" stroke-opacity="0.049999999999999996" stroke-width="5" transform="translate(1, 1)"></path><path fill="none" class="highcharts-label-box highcharts-shadow" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 38.099999999999994 L -5.5 32.099999999999994 L 0.5 26.099999999999994 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#000000" stroke-opacity="0.09999999999999999" stroke-width="3" transform="translate(1, 1)"></path><path fill="none" class="highcharts-label-box highcharts-shadow" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 38.099999999999994 L -5.5 32.099999999999994 L 0.5 26.099999999999994 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#000000" stroke-opacity="0.15" stroke-width="1" transform="translate(1, 1)"></path><path fill="rgba(247,247,247,0.85)" class="highcharts-label-box" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 38.099999999999994 L -5.5 32.099999999999994 L 0.5 26.099999999999994 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#4f81bd" stroke-width="1"></path></g></g>
# <div class="highcharts-tooltip" style="position: absolute; left: 0px; top: 0px; opacity: 1; visibility: inherit;"><div class="highcharts-label highcharts-tooltip-box highcharts-color-none" style="position: absolute; left: 41px; top: 120px; opacity: 1; visibility: inherit;"><span style="position: absolute; font-family: &quot;Lucida Grande&quot;, &quot;Lucida Sans Unicode&quot;, Arial, Helvetica, sans-serif; font-size: 12px; white-space: nowrap; margin-left: 0px; margin-top: 0px; left: 0px; top: 0px; color: rgb(51, 51, 51);" data-z-index="1"><div class="tooltip-box"><span class="tooltip-date">Jul 1997</span><hr class="tooltip-divider"><span class="hawk-tt tooltip-value" style="color: rgb(51, 51, 51);"> 56.7 Points</span></div></span></div></div>
# Found first point data: <div class="highcharts-tooltip" style="position: absolute; left: 0px; top: 0px; opacity: 1; visibility: inherit;"><div class="highcharts-label highcharts-tooltip-box highcharts-color-none" style="position: absolute; left: 41px; top: 120px; opacity: 1; visibility: inherit;"><span style="position: absolute; font-family: &quot;Lucida Grande&quot;, &quot;Lucida Sans Unicode&quot;, Arial, Helvetica, sans-serif; font-size: 12px; white-space: nowrap; margin-left: 0px; margin-top: 0px; left: 0px; top: 0px; color: rgb(51, 51, 51);" data-z-index="1"><div class="tooltip-box"><span class="tooltip-date">Jul 1997</span><hr class="tooltip-divider"><span class="hawk-tt tooltip-value" style="color: rgb(51, 51, 51);"> 56.7 Points</span></div></span></div></div>
# Moving to last point at viewport coordinates (815.0, 614.5)
# <g class="highcharts-tooltip" data-z-index="8" opacity="1" y="-9999"><g class="highcharts-label highcharts-tooltip-box highcharts-color-none" transform="translate(590,159)" style="cursor: default; white-space: nowrap;"><path fill="none" class="highcharts-label-box highcharts-shadow" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 25.871428571429988 L 96.5 31.871428571429988 L 90.5 37.87142857142999 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#000000" stroke-opacity="0.049999999999999996" stroke-width="5" transform="translate(1, 1)"></path><path fill="none" class="highcharts-label-box highcharts-shadow" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 25.871428571429988 L 96.5 31.871428571429988 L 90.5 37.87142857142999 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#000000" stroke-opacity="0.09999999999999999" stroke-width="3" transform="translate(1, 1)"></path><path fill="none" class="highcharts-label-box highcharts-shadow" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 25.871428571429988 L 96.5 31.871428571429988 L 90.5 37.87142857142999 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#000000" stroke-opacity="0.15" stroke-width="1" transform="translate(1, 1)"></path><path fill="rgba(247,247,247,0.85)" class="highcharts-label-box" d="M 3.5 0.5 L 87.5 0.5 C 90.5 0.5 90.5 0.5 90.5 3.5 L 90.5 25.871428571429988 L 96.5 31.871428571429988 L 90.5 37.87142857142999 L 90.5 60.5 C 90.5 63.5 90.5 63.5 87.5 63.5 L 3.5 63.5 C 0.5 63.5 0.5 63.5 0.5 60.5 L 0.5 3.5 C 0.5 0.5 0.5 0.5 3.5 0.5" stroke="#4f81bd" stroke-width="1"></path></g></g>
# <div class="highcharts-tooltip" style="position: absolute; left: 0px; top: 0px; opacity: 1; visibility: inherit;"><div class="highcharts-label highcharts-tooltip-box highcharts-color-none" style="position: absolute; left: 590px; top: 159px; opacity: 1; visibility: inherit;"><span style="position: absolute; font-family: &quot;Lucida Grande&quot;, &quot;Lucida Sans Unicode&quot;, Arial, Helvetica, sans-serif; font-size: 12px; white-space: nowrap; margin-left: 0px; margin-top: 0px; left: 0px; top: 0px; color: rgb(51, 51, 51);" data-z-index="1"><div class="tooltip-box"><span class="tooltip-date">Nov 2024</span><hr class="tooltip-divider"><span class="hawk-tt tooltip-value" style="color: rgb(51, 51, 51);"> 52.1 Points</span></div></span></div></div>
# Found last point data: <div class="highcharts-tooltip" style="position: absolute; left: 0px; top: 0px; opacity: 1; visibility: inherit;"><div class="highcharts-label highcharts-tooltip-box highcharts-color-none" style="position: absolute; left: 590px; top: 159px; opacity: 1; visibility: inherit;"><span style="position: absolute; font-family: &quot;Lucida Grande&quot;, &quot;Lucida Sans Unicode&quot;, Arial, Helvetica, sans-serif; font-size: 12px; white-space: nowrap; margin-left: 0px; margin-top: 0px; left: 0px; top: 0px; color: rgb(51, 51, 51);" data-z-index="1"><div class="tooltip-box"><span class="tooltip-date">Nov 2024</span><hr class="tooltip-divider"><span class="hawk-tt tooltip-value" style="color: rgb(51, 51, 51);"> 52.1 Points</span></div></span></div></div>
# Creating date index for self.series, using start and end dates from tooltips stored in self.start_end.
# Date index created successfully. Take a look at the final series:
#
#  1997-07-01    223.400000
# 1997-08-01    268.071429
# 1997-09-01    219.185714
# 1997-10-01    225.928571
# 1997-11-01    238.571429
#                  ...
# 2024-07-01    178.728571
# 2024-08-01    179.571429
# 2024-09-01    208.228571
# 2024-10-01    217.500000
# 2024-11-01    184.628571
# Freq: MS, Name: US_ISM_Services_PMI, Length: 329, dtype: float64
# axisY0 =  35 axisY1 = 70
# unit_per_pix:  0.11824324324324324
# datamax:  67.608 datamin:  37.909
# Successfully scraped time-series from chart at:  https://tradingeconomics.com/united-states/non-manufacturing-pmi
#  1997-07-01    56.744943
# 1997-08-01    62.026980
# 1997-09-01    56.246638
# 1997-10-01    57.043926
# 1997-11-01    58.538842
#                 ...
# 2024-07-01    51.462906
# 2024-08-01    51.562567
# 2024-09-01    54.951044
# 2024-10-01    56.047315
# 2024-11-01    52.160534
# Freq: MS, Name: US_ISM_Services_PMI, Length: 329, dtype: float64

# %%
sel2.series.plot()

# %%
search = scr.search_TE(browser='firefox', headless=True)

# %%
search.search_trading_economics(search_term="private sector credit")
search.result_table
# Out:
# Loading page...
# Waiting for search box...
# Clicking search box...
# Entering search term: private sector credit
# Submitting search...
#                      country                 metric  \
# result
# 0               country list  private sector credit
# 1              united states  private sector credit
# 2                  euro area  private sector credit
# 3                    germany  private sector credit
# 4                     brazil  private sector credit
# 5                     russia  private sector credit
# 6                     mexico  private sector credit
# 7                  australia  private sector credit
# 8                      spain  private sector credit
# 9                     turkey  private sector credit
# 10                    sweden  private sector credit
# 11                   ireland  private sector credit
# 12      united arab emirates  private sector credit
# 13                    israel  private sector credit
# 14                 singapore  private sector credit
# 15                   nigeria  private sector credit
# 16                bangladesh  private sector credit
# 17              south africa  private sector credit
# 18                     chile  private sector credit
# 19                  colombia  private sector credit
# 20            czech republic  private sector credit
# 21                    greece  private sector credit
# 22                     qatar  private sector credit
# 23                      peru  private sector credit
# 24                   hungary  private sector credit
# 25                 venezuela  private sector credit
# 26               new zealand  private sector credit
#
#                                                       url
# result
# 0       https://tradingeconomics.com/country-list/priv...
# 1       https://tradingeconomics.com/united-states/pri...
# 2       https://tradingeconomics.com/euro-area/private...
# 3       https://tradingeconomics.com/germany/private-s...
# 4       https://tradingeconomics.com/brazil/private-se...
# 5       https://tradingeconomics.com/russia/private-se...
# 6       https://tradingeconomics.com/mexico/private-se...
# 7       https://tradingeconomics.com/australia/private...
# 8       https://tradingeconomics.com/spain/private-sec...
# 9       https://tradingeconomics.com/turkey/private-se...
# 10      https://tradingeconomics.com/sweden/private-se...
# 11      https://tradingeconomics.com/ireland/private-s...
# 12      https://tradingeconomics.com/united-arab-emira...
# 13      https://tradingeconomics.com/israel/private-se...
# 14      https://tradingeconomics.com/singapore/private...
# 15      https://tradingeconomics.com/nigeria/private-s...
# 16      https://tradingeconomics.com/bangladesh/privat...
# 17      https://tradingeconomics.com/south-africa/priv...
# 18      https://tradingeconomics.com/chile/private-sec...
# 19      https://tradingeconomics.com/colombia/private-...
# 20      https://tradingeconomics.com/czech-republic/pr...
# 21      https://tradingeconomics.com/greece/private-se...
# 22      https://tradingeconomics.com/qatar/private-sec...
# 23      https://tradingeconomics.com/peru/private-sect...
# 24      https://tradingeconomics.com/hungary/private-s...
# 25      https://tradingeconomics.com/venezuela/private...
# 26      https://tradingeconomics.com/new-zealand/priva...

# %%
us_credit = search.get_data(1)
#us_credit.plot_series()
# Out:
# Scraping data from: https://tradingeconomics.com/united-states/private-sector-credit
# Page at  https://tradingeconomics.com/united-states/private-sector-credit , loaded successfully.
# Clicked the MAX button successfully.
# Error scraping chart: invalid literal for int() with base 10: '12.2K'

# %%
sel = scr.TE_Scraper(browser='firefox')
sel.load_page("https://tradingeconomics.com/united-states/private-sector-credit")
sel.click_button("a.hawk-chartOptions-datePicker-cnt-btn:nth-child(5)")
yaxys = sel.get_y_axis()
yaxys
sel.get_element()
series = sel.series_from_element(invert_the_series=True)
sel.series
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 4
#       2 sel.load_page("https://tradingeconomics.com/united-states/private-sector-credit")
#       3 sel.click_button("a.hawk-chartOptions-datePicker-cnt-btn:nth-child(5)")
# ----> 4 yaxys = sel.get_y_axis()
#       5 yaxys
#       6 sel.get_element()
#
# File c:\Users\OtherCat\Documents\Code\Python\Scraping\scrape.py:492, in TE_Scraper.get_y_axis(self)
#     490 yax = soup2.select('g.highcharts-axis-labels.highcharts-yaxis-labels')
#     491 textels = yax[1].find_all('text')
# --> 492 yaxlabs = [int(text.get_text()) for text in textels]
#     493 pixheights = [float(height) for height in y_heights]
#     494 pixheights.sort()
#
# File c:\Users\OtherCat\Documents\Code\Python\Scraping\scrape.py:492, in <listcomp>(.0)
#     490 yax = soup2.select('g.highcharts-axis-labels.highcharts-yaxis-labels')
#     491 textels = yax[1].find_all('text')
# --> 492 yaxlabs = [int(text.get_text()) for text in textels]
#     493 pixheights = [float(height) for height in y_heights]
#     494 pixheights.sort()
#
# ValueError: invalid literal for int() with base 10: '2.5K'
